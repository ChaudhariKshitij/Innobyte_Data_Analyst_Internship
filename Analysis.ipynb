# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("SampleSuperstore.csv")

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %% [markdown]
# ## Data Cleaning

# %%
df=df.dropna()

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9977 rows x 13 columns]

# %%
profit=df[df['Profit']>0]
profit
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5     Standard Class   Consumer  United States      Los Angeles  California
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.960         2
# 1           42420  South        Furniture       Chairs  731.940         3
# 2           90036   West  Office Supplies       Labels   14.620         2
# 4           33311  South  Office Supplies      Storage   22.368         2
# 5           90032   West        Furniture  Furnishings   48.860         7
# ...           ...    ...              ...          ...      ...       ...
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount    Profit
# 0          0.0   41.9136
# 1          0.0  219.5820
# 2          0.0    6.8714
# 4          0.2    2.5164
# 5          0.0   14.1694
# ...        ...       ...
# 9989       0.2    4.1028
# 9990       0.0   15.6332
# 9991       0.2   19.3932
# 9992       0.0   13.3200
# 9993       0.0   72.9480
#
# [8043 rows x 13 columns]

# %%
profit[['Sales','Quantity','Discount','Profit']].describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   8043.000000  8043.000000  8043.000000  8043.000000
# mean     223.807848     3.795847     0.081095    54.998684
# std      600.839190     2.246465     0.098895   213.904683
# min        0.990000     1.000000     0.000000     0.062800
# 25%       17.940000     2.000000     0.000000     5.320500
# 50%       51.150000     3.000000     0.000000    13.320000
# 75%      191.982000     5.000000     0.200000    40.564650
# max    17499.950000    14.000000     0.400000  8399.976000

# %%
profit.groupby(by='City').sum().sort_values('Profit',ascending=True).head(10)
# Out:
#                         Ship Mode      Segment        Country         State  \
# City
# Jupiter              Second Class     Consumer  United States       Florida
# Bethlehem             First Class     Consumer  United States  Pennsylvania
# San Luis Obispo    Standard Class     Consumer  United States    California
# Arlington Heights  Standard Class     Consumer  United States      Illinois
# Cuyahoga Falls     Standard Class    Corporate  United States          Ohio
# Springdale         Standard Class  Home Office  United States      Arkansas
# Keller               Second Class     Consumer  United States         Texas
# Altoona               First Class    Corporate  United States  Pennsylvania
# Layton               Second Class     Consumer  United States          Utah
# Margate            Standard Class     Consumer  United States       Florida
#
#                    Postal Code   Region         Category Sub-Category   Sales  \
# City
# Jupiter                  33458    South  Office Supplies          Art   2.064
# Bethlehem                18018     East  Office Supplies   Appliances   9.480
# San Luis Obispo          93405     West  Office Supplies    Fasteners   3.620
# Arlington Heights        60004  Central  Office Supplies          Art  14.112
# Cuyahoga Falls           44221     East        Furniture  Furnishings   8.352
# Springdale               72762    South  Office Supplies          Art   4.300
# Keller                   76248  Central  Office Supplies       Labels   6.000
# Altoona                  16602     East  Office Supplies          Art  16.032
# Layton                   84041     West  Office Supplies    Fasteners   4.960
# Margate                  33063    South  Office Supplies          Art  15.552
#
#                    Quantity  Discount  Profit
# City
# Jupiter                   1       0.2  0.1548
# Bethlehem                 3       0.2  0.7110
# San Luis Obispo           2       0.0  1.1946
# Arlington Heights         6       0.2  1.2348
# Cuyahoga Falls            6       0.2  1.2528
# Springdale                2       0.0  1.4190
# Keller                    2       0.2  2.1000
# Altoona                   6       0.2  2.2044
# Layton                    4       0.0  2.3312
# Margate                   3       0.2  2.3328

# %%
loss=df[df['Profit']<0]
loss
# Out:
#            Ship Mode      Segment        Country             City  \
# 3     Standard Class     Consumer  United States  Fort Lauderdale
# 14    Standard Class  Home Office  United States       Fort Worth
# 15    Standard Class  Home Office  United States       Fort Worth
# 23      Second Class     Consumer  United States     Philadelphia
# 27    Standard Class     Consumer  United States     Philadelphia
# ...              ...          ...            ...              ...
# 9920  Standard Class    Corporate  United States            Bryan
# 9921  Standard Class  Home Office  United States            Akron
# 9931  Standard Class     Consumer  United States   San Bernardino
# 9937    Second Class    Corporate  United States      Los Angeles
# 9962     First Class  Home Office  United States          Houston
#
#              State  Postal Code   Region         Category Sub-Category  \
# 3          Florida        33311    South        Furniture       Tables
# 14           Texas        76106  Central  Office Supplies   Appliances
# 15           Texas        76106  Central  Office Supplies      Binders
# 23    Pennsylvania        19140     East        Furniture       Chairs
# 27    Pennsylvania        19140     East        Furniture    Bookcases
# ...            ...          ...      ...              ...          ...
# 9920         Texas        77803  Central  Office Supplies      Binders
# 9921          Ohio        44312     East  Office Supplies      Binders
# 9931    California        92404     West        Furniture    Bookcases
# 9937    California        90049     West        Furniture       Tables
# 9962         Texas        77041  Central        Furniture    Bookcases
#
#           Sales  Quantity  Discount     Profit
# 3      957.5775         5      0.45  -383.0310
# 14      68.8100         5      0.80  -123.8580
# 15       2.5440         3      0.80    -3.8160
# 23      71.3720         2      0.30    -1.0196
# 27    3083.4300         7      0.50 -1665.0522
# ...         ...       ...       ...        ...
# 9920    22.3860         7      0.80   -35.8176
# 9921     5.7420         3      0.70    -4.5936
# 9931   683.3320         4      0.15   -40.1960
# 9937    71.0880         2      0.20    -1.7772
# 9962   383.4656         4      0.32   -67.6704
#
# [1869 rows x 13 columns]

# %%
loss[['Sales','Quantity','Discount','Profit']].describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   1869.000000  1869.000000  1869.000000  1869.000000
# mean     250.627190     3.764045     0.480813   -83.527549
# std      715.426811     2.142032     0.235053   284.565230
# min        0.444000     1.000000     0.100000 -6599.978000
# 25%       12.544000     2.000000     0.200000   -58.687200
# 50%       71.088000     3.000000     0.400000   -18.106800
# 75%      285.480000     5.000000     0.700000    -6.286000
# max    22638.480000    14.000000     0.800000    -0.089500

# %%
total_sales = df['Sales'].sum()
total_sales
# Out:
# 2296195.5903

# %%
sales_by_category = df.groupby('Category')['Sales'].sum()
sales_by_category
# Out:
# Category
# Furniture          741306.3133
# Office Supplies    718735.2440
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
sales_by_subcategory = df.groupby('Sub-Category')['Sales'].sum()
sales_by_subcategory
# Out:
# Sub-Category
# Accessories    167380.3180
# Appliances     107532.1610
# Art             27107.0320
# Binders        203409.1690
# Bookcases      114879.9963
# Chairs         327777.7610
# Copiers        149528.0300
# Envelopes       16476.4020
# Fasteners        3024.2800
# Furnishings     91683.0240
# Labels          12444.9120
# Machines       189238.6310
# Paper           78224.1420
# Phones         330007.0540
# Storage        223843.6080
# Supplies        46673.5380
# Tables         206965.5320
# Name: Sales, dtype: float64

# %%
total_profit = df['Profit'].sum()
total_profit
# Out:
# 286241.4226

# %%
profit_by_category = df.groupby('Category')['Profit'].sum()
profit_by_category
# Out:
# Category
# Furniture           18421.8137
# Office Supplies    122364.6608
# Technology         145454.9481
# Name: Profit, dtype: float64

# %%
profit_by_subcategory = df.groupby('Sub-Category')['Profit'].sum()
profit_by_subcategory
# Out:
# Sub-Category
# Accessories    41936.6357
# Appliances     18138.0054
# Art             6524.6118
# Binders        30228.0003
# Bookcases      -3472.5560
# Chairs         26567.1278
# Copiers        55617.8249
# Envelopes       6964.1767
# Fasteners        949.5182
# Furnishings    13052.7230
# Labels          5526.3820
# Machines        3384.7569
# Paper          33944.2395
# Phones         44515.7306
# Storage        21278.8264
# Supplies       -1189.0995
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %%
segment_sales = df.groupby('Segment')['Sales'].sum()
segment_sales
# Out:
# Segment
# Consumer       1.160833e+06
# Corporate      7.060701e+05
# Home Office    4.292927e+05
# Name: Sales, dtype: float64

# %%
segment_profit = df.groupby('Segment')['Profit'].sum()
segment_profit
# Out:
# Segment
# Consumer       134007.4413
# Corporate       91954.9798
# Home Office     60279.0015
# Name: Profit, dtype: float64

# %%
sales_by_country = df.groupby('Country')['Sales'].sum()
sales_by_country
# Out:
# Country
# United States    2.296196e+06
# Name: Sales, dtype: float64

# %%
profit_by_region = df.groupby('Region')['Profit'].sum()
profit_by_region
# Out:
# Region
# Central     39655.8752
# East        91506.3092
# South       46749.4303
# West       108329.8079
# Name: Profit, dtype: float64

# %%
top_categories = df.groupby('Category')['Sales'].sum().nlargest(5)
top_categories
# Out:
# Category
# Technology         836154.0330
# Furniture          741306.3133
# Office Supplies    718735.2440
# Name: Sales, dtype: float64

# %%
profitable_categories = df.groupby('Category')['Profit'].sum().nlargest(5)
profitable_categories
# Out:
# Category
# Technology         145454.9481
# Office Supplies    122364.6608
# Furniture           18421.8137
# Name: Profit, dtype: float64

# %%
discount_impact = df.groupby('Discount')[['Sales', 'Profit']].mean()
discount_impact
# Out:
#                Sales      Profit
# Discount
# 0.00      227.131306   67.024108
# 0.10      578.397351   96.055074
# 0.15      529.971567   27.288298
# 0.20      209.281397   24.721217
# 0.30      455.510102  -45.828401
# 0.32      536.794770  -88.560656
# 0.40      565.134874 -111.927429
# 0.45      498.634000 -226.646464
# 0.50      892.705152 -310.703456
# 0.60       48.150000  -43.077212
# 0.70       97.177708  -95.874060
# 0.80       56.723050 -102.116395

# %%
ship_mode_sales = df.groupby('Ship Mode')['Sales'].sum()
ship_mode_sales
# Out:
# Ship Mode
# First Class       3.513805e+05
# Same Day          1.283217e+05
# Second Class      4.591770e+05
# Standard Class    1.357316e+06
# Name: Sales, dtype: float64

# %%
ship_mode_profit = df.groupby('Ship Mode')['Profit'].sum()
ship_mode_profit
# Out:
# Ship Mode
# First Class        48953.6561
# Same Day           15871.8869
# Second Class       57446.6516
# Standard Class    163969.2280
# Name: Profit, dtype: float64

# %%
quantity_sold = df['Quantity'].sum()
quantity_sold
# Out:
# 37820

# %%
print("Total Sales:", total_sales,'\n')
print("Sales by Category:\n", sales_by_category,'\n')
print("Sales by Sub-Category:\n", sales_by_subcategory,'\n')
print("Total Profit:", total_profit,'\n')
print("Profit by Category:\n", profit_by_category,'\n')
print("Profit by Sub-Category:\n", profit_by_subcategory,'\n')
print("Segment-wise Sales:\n", segment_sales,'\n')
print("Segment-wise Profit:\n", segment_profit,'\n')
print("Sales by Country:\n", sales_by_country,'\n')
print("Profit by Region:\n", profit_by_region,'\n')
print("Top Categories by Sales:\n", top_categories,'\n')
print("Top Categories by Profit:\n", profitable_categories,'\n')
print("Discount Impact:\n", discount_impact,'\n')
print("Ship Mode-wise Sales:\n", ship_mode_sales,'\n')
print("Ship Mode-wise Profit:\n", ship_mode_profit,'\n')
print("Total Quantity Sold:", quantity_sold)
# Out:
# Total Sales: 2296195.5903
#
# Sales by Category:
#  Category
# Furniture          741306.3133
# Office Supplies    718735.2440
# Technology         836154.0330
# Name: Sales, dtype: float64
#
# Sales by Sub-Category:
#  Sub-Category
# Accessories    167380.3180
# Appliances     107532.1610
# Art             27107.0320
# Binders        203409.1690
# Bookcases      114879.9963
# Chairs         327777.7610
# Copiers        149528.0300
# Envelopes       16476.4020
# Fasteners        3024.2800
# Furnishings     91683.0240
# Labels          12444.9120
# Machines       189238.6310
# Paper           78224.1420
# Phones         330007.0540
# Storage        223843.6080
# Supplies        46673.5380
# Tables         206965.5320
# Name: Sales, dtype: float64
#
# Total Profit: 286241.4226
#
# Profit by Category:
#  Category
# Furniture           18421.8137
# Office Supplies    122364.6608
# Technology         145454.9481
# Name: Profit, dtype: float64
#
# Profit by Sub-Category:
#  Sub-Category
# Accessories    41936.6357
# Appliances     18138.0054
# Art             6524.6118
# Binders        30228.0003
# Bookcases      -3472.5560
# Chairs         26567.1278
# Copiers        55617.8249
# Envelopes       6964.1767
# Fasteners        949.5182
# Furnishings    13052.7230
# Labels          5526.3820
# Machines        3384.7569
# Paper          33944.2395
# Phones         44515.7306
# Storage        21278.8264
# Supplies       -1189.0995
# Tables        -17725.4811
# Name: Profit, dtype: float64
#
# Segment-wise Sales:
#  Segment
# Consumer       1.160833e+06
# Corporate      7.060701e+05
# Home Office    4.292927e+05
# Name: Sales, dtype: float64
#
# Segment-wise Profit:
#  Segment
# Consumer       134007.4413
# Corporate       91954.9798
# Home Office     60279.0015
# Name: Profit, dtype: float64
#
# Sales by Country:
#  Country
# United States    2.296196e+06
# Name: Sales, dtype: float64
#
# Profit by Region:
#  Region
# Central     39655.8752
# East        91506.3092
# South       46749.4303
# West       108329.8079
# Name: Profit, dtype: float64
#
# Top Categories by Sales:
#  Category
# Technology         836154.0330
# Furniture          741306.3133
# Office Supplies    718735.2440
# Name: Sales, dtype: float64
#
# Top Categories by Profit:
#  Category
# Technology         145454.9481
# Office Supplies    122364.6608
# Furniture           18421.8137
# Name: Profit, dtype: float64
#
# Discount Impact:
#                 Sales      Profit
# Discount
# 0.00      227.131306   67.024108
# 0.10      578.397351   96.055074
# 0.15      529.971567   27.288298
# 0.20      209.281397   24.721217
# 0.30      455.510102  -45.828401
# 0.32      536.794770  -88.560656
# 0.40      565.134874 -111.927429
# 0.45      498.634000 -226.646464
# 0.50      892.705152 -310.703456
# 0.60       48.150000  -43.077212
# 0.70       97.177708  -95.874060
# 0.80       56.723050 -102.116395
#
# Ship Mode-wise Sales:
#  Ship Mode
# First Class       3.513805e+05
# Same Day          1.283217e+05
# Second Class      4.591770e+05
# Standard Class    1.357316e+06
# Name: Sales, dtype: float64
#
# Ship Mode-wise Profit:
#  Ship Mode
# First Class        48953.6561
# Same Day           15871.8869
# Second Class       57446.6516
# Standard Class    163969.2280
# Name: Profit, dtype: float64
#
# Total Quantity Sold: 37820

# %%
plt.figure(figsize=(10, 6))
sales_by_category.plot(kind='bar', color='skyblue')
plt.title('Sales by Category')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
profit_by_category.plot(kind='bar', color='lightgreen')
plt.title('Profit by Category')
plt.xlabel('Category')
plt.ylabel('Profit')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.pie(segment_sales, labels=segment_sales.index, autopct='%1.1f%%', startangle=140)
plt.title('Segment-wise Sales')
plt.show()

# %%
plt.figure(figsize=(10, 6))
discount_impact.plot(kind='line')
plt.title('Discount Impact')
plt.xlabel('Discount')
plt.ylabel('Average Sales/Profit')
plt.xticks(discount_impact.index)
plt.grid(True)
plt.show()

# %%
numerical_features=df[['Sales','Quantity','Discount','Profit']]
correlation_matrix=numerical_features.corr()

plt.figure(figsize=(10, 8))
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='nearest')
plt.colorbar()
plt.title('Correlation Matrix')
plt.xticks(range(len(correlation_matrix)), correlation_matrix.columns, rotation=90)
plt.yticks(range(len(correlation_matrix)), correlation_matrix.columns)
plt.show()

# %%
plt.rcParams['figure.figsize']=(15,5)
plt.bar(loss['Sub-Category'],loss['Sales'])
plt.rcParams.update({'font.size':10})
plt.xlabel('Sub_Category')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
plt.rcParams['figure.figsize']=(20,8)
plt.bar(df['Sub-Category'],df['Sales'])
plt.rcParams.update({'font.size':10})
plt.xlabel('Sub_Category')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')
